# %% [markdown]
#                                                  Anand International College of Engineering
#                                                  Subject – Data Science with AI & MLops
#                                                  Topic – Basic Python & Python data types
#
#                                                           Assignment 1:

# %% [markdown]
# 1. Create a string variable with your name and perform the following operations:
# Print the first character
# Print the last character
# Print the length of the string
# Convert the string to uppercase
# Convert the string to lowercase
# Reverse the string using slicing

# %%
name= "Krishan Kumar Saini"
print("first character : ",name[0])
print("last character : ",name[-1])
print("length of the string : ",len(name))
print("upprecase : ",name.upper())
print("lowercase : ",name.lower())
print("Reverse the string", name[::-1])
# Out:
# first character :  K
# last character :  i
# length of the string :  19
# upprecase :  KRISHAN KUMAR SAINI
# lowercase :  krishan kumar saini
# Reverse the string iniaS ramuK nahsirK

# %% [markdown]
# 2. Write a Python program to perform string slicing on a given string:
# Print the first four characters
# Print characters from index 2 to 5
# Print the complete string in reverse order

# %%
name= "Krishan Kumar Saini"
print ("first 4 characters :",name[0:4])
print ("first 4 characters :",name[2:6])
print ("first 4 characters :",name[::-1])
# Out:
# first 4 characters : Kris
# first 4 characters : isha
# first 4 characters : iniaS ramuK nahsirK

# %% [markdown]
# 3. Create a list containing numbers and perform the following operations:
# Add an element using append()
# Insert an element at a specific position
# Remove an element using remove()
# Delete the last element using pop()
# Reverse the list
# Sort the list
# Find the length of the list
# Count the occurrence of an element

# %%
l = [10, 20, 30, 40, 20]
print("Original List :", l)
l.append(50)
print("After Append :", l)
l.insert(2, 25)
print("After Insert :", l)
l.remove(20)
print("After Remove :", l)
l.pop()
print("After Pop :", l)
l.reverse()
print("After Reverse :", l)
l.sort()
print("After Sort :", l)
print("Length of List :", len(l))
print("Count of 20 :", l.count(20))
# Out:
# Original List : [10, 20, 30, 40, 20]
# After Append : [10, 20, 30, 40, 20, 50]
# After Insert : [10, 20, 25, 30, 40, 20, 50]
# After Remove : [10, 25, 30, 40, 20, 50]
# After Pop : [10, 25, 30, 40, 20]
# After Reverse : [20, 40, 30, 25, 10]
# After Sort : [10, 20, 25, 30, 40]
# Length of List : 5
# Count of 20 : 1

# %% [markdown]
# 4. Create a tuple containing 5 subjects. Perform the following operations:
# Print the first element
# Print the last element
# Print the length of the tuple
# Print elements using slicing
# Find the maximum, minimum, and sum of numerical tuple elements

# %%
t = ("Maths", "Physics", "Chemistry", "English", "Computer")
print("Tuple :", t)
print("First Element :", t[0])
print("Last Element :", t[-1])
print("Length :", len(t))
print("slicing :", t[1:4])

n = (10, 20, 30, 40, 50)
print(n)
print("Maximum :", max(n))
print("Minimum :", min(n))
print("Sum :", sum(n))
# Out:
# Tuple = ('Maths', 'Physics', 'Chemistry', 'English', 'Computer')
# First Element = Maths
# Last Element = Computer
# Length = 5
# slicing : ('Physics', 'Chemistry', 'English')
# (10, 20, 30, 40, 50)
# Maximum = 50
# Minimum = 10
# Sum = 150

# %% [markdown]
# 5. Write a Python program to demonstrate tuple packing and unpacking. Create
# a tuple of four values and assign them to four separate variables.

# %%
t=(1,2,3,4) 

a,b,c,d = t
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# 6. Create a dictionary containing student details:
# o Name
# o Age
# o Course
# o Address
# Perform the following operations:
# o Print all keys
# o Print all values
# o Print all items
# o Update the Address
# o Add a new key called "Branch"

# %%
student={
    "name":"krishan",
    "age":21,
    "course":"23cs048",
    "address":"lalsot",
}
print("keys: ",student.keys())
print("values: ",student.values())
print("items: ",student.items())
student.update({"address":"jaipur"})
print("after update :",student)
student.setdefault("branch","CSE")
print("after add branch :",student)
# Out:
# keys:  dict_keys(['name', 'age', 'course', 'address'])
# values:  dict_values(['krishan', 21, '23cs048', 'lalsot'])
# items:  dict_items([('name', 'krishan'), ('age', 21), ('course', '23cs048'), ('address', 'lalsot')])
# after update : {'name': 'krishan', 'age': 21, 'course': '23cs048', 'address': 'jaipur'}
# after update : {'name': 'krishan', 'age': 21, 'course': '23cs048', 'address': 'jaipur', 'branch': 'CSE'}

# %% [markdown]
# 7. Write a Python program to access an element from a nested list.
# Example:
# [1, 2, 3, 4, [2, 5], 7]
# Print the value 5 using indexing

# %%
lst = [1, 2, 3, 4, [3,6], 7]

print(lst[4][1])
print(lst[4][0])
# Out:
# 6
# 3

# %% [markdown]
# 8. Write a Python program to take a number as input from the user and:
# o Add 10 using the += operator
# o Print the updated value

# %%
num = int(input("Enter a number: "))
print(num)
num += 10
print("Add 10 in number :", num)
# Out:
# 12
# Add 10 in number : 22

# %% [markdown]
# 9. Write a Python program to demonstrate type casting:
# o Take two numbers as input from the user
# o Convert them to integers
# o Print their multiplication

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
mul = a * b
print("Multiplication =", mul)
# Out:
# Multiplication = 6

# %% [markdown]
# 10.Create a dictionary and demonstrate the use of:
# o get()
# o keys()
# o values()
# o items()

# %%
student={
    "name":"krishan",
    "age":21,
    "course":"23cs048",
    "address":"lalsot",
}
print(student.get("name"))
print("keys: ",student.keys())
print("values: ",student.values())
print("items: ",student.items())
# Out:
# krishan
# keys:  dict_keys(['name', 'age', 'course', 'address'])
# values:  dict_values(['krishan', 21, '23cs048', 'lalsot'])
# items:  dict_items([('name', 'krishan'), ('age', 21), ('course', '23cs048'), ('address', 'lalsot')])

# %% [markdown]
# 11.Create a copy of a list using copy() and print both the original and copied
# lists.

# %%
l1=[1,3,4,2,"hii"]
l2=l1.copy()
l2[4]= "hello"
print("Original list :",l1)
print("Copy list :",l2)
# Out:
# Original list : [1, 3, 4, 2, 'hii']
# Copy list : [1, 3, 4, 2, 'hello']
